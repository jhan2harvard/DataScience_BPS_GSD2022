# %% [markdown]
# ### Harvard GSD  J-Term 2022
# ### Introduction to Data Science for Building Simulation and Architectural Design
# ***
# Instructor: Jung Min Han, jhan2@gsd.harvard.edu <br>
# Date/Time: Jan 3-7/ 10:00 - 11:30 a.m. <br>
# ***
#
# Pease copy this colab notebook and rename it before you start!
#
# ---

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Read and Manupulation: weather file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# pandas data frame from csv
def getPandasFromFile(path, fileName, theSkipRow):
    path = os.path.join(path , fileName)
    return pd.read_csv(path, skiprows= theSkipRow , header=None, index_col = False)
def SavePandasToCSV(d, path):
    d.to_csv(path)
    return "done!!"

# modify the following file path for your GoogleDrive
FILEPATH = '/content/drive/My Drive/Colab Notebooks/J_Term/USA_MA_Boston-Logan.Intl.AP.725090_TMY3.epw'

df = getPandasFromFile("",FILEPATH,8)
df
# Out:
#         0   1   2   3   4   ... 30  31      32     33    34
# 0     1976   1   1   1   0  ...  0  88  999.00  999.0  99.0
# 1     1976   1   1   2   0  ...  0  88  999.00  999.0  99.0
# 2     1976   1   1   3   0  ...  0  88  999.00  999.0  99.0
# 3     1976   1   1   4   0  ...  0  88  999.00  999.0  99.0
# 4     1976   1   1   5   0  ...  0  88  999.00  999.0  99.0
# ...    ...  ..  ..  ..  ..  ... ..  ..     ...    ...   ...
# 8755  2003  12  31  20   0  ...  0  88    0.16    0.0   1.0
# 8756  2003  12  31  21   0  ...  0  88    0.16    0.0   1.0
# 8757  2003  12  31  22   0  ...  0  88    0.16    0.0   1.0
# 8758  2003  12  31  23   0  ...  0  88    0.16    0.0   1.0
# 8759  2003  12  31  24   0  ...  0  88    0.16    0.0   1.0
#
# [8760 rows x 35 columns]

# %%
# rename dataframe with known column names

theDf =df.rename(index=str, columns={0:"year", 1: "Month", 2: "Day", 3:"Hour",4:"Minute",6:"DB_temp",
                                     7:"Dew_Point",
                                     8:"RH",9:"P", 10:"Horiz_Rad",11:"Normal_Rad",12:"Sky_Rad",
                                     13:"G_Horiz_Rad",14:"Dir_Normal_Rad",15:"Diff_Horiz_Rad",
                                     16:"G_Horiz_Illu",17:"Dir_Normal_Illu",18:"Diff_Horiz_Illu",
                                     19:"Zenith_Illu",20:"Wind_Direction",21:"Wind_Speed",
                                     22:"Total_Sky_Cov",23:"Opaque_Sky_Cov",24:"Visibility",
                                     25:"field_Ceiling_H",26:"Whtr_Observ",27:"Whtr_Codes",
                                     28:"Pred_Water",29:"AeroesOptical_D",30:"Snow_Depth",
                                     31:"Days_Since_Snow"
                                    })

# %%
# your code here
# Out:
#    year  Month  Day  Hour  ...  Days_Since_Snow     32     33    34
# 0  1976      1    1     1  ...               88  999.0  999.0  99.0
# 1  1976      1    1     2  ...               88  999.0  999.0  99.0
# 2  1976      1    1     3  ...               88  999.0  999.0  99.0
#
# [3 rows x 35 columns]

# %%
# check the the column names

# your code here
# Out:
# array(['year', 'Month', 'Day', 'Hour', 'Minute', 5, 'DB_temp',
#        'Dew_Point', 'RH', 'P', 'Horiz_Rad', 'Normal_Rad', 'Sky_Rad',
#        'G_Horiz_Rad', 'Dir_Normal_Rad', 'Diff_Horiz_Rad', 'G_Horiz_Illu',
#        'Dir_Normal_Illu', 'Diff_Horiz_Illu', 'Zenith_Illu',
#        'Wind_Direction', 'Wind_Speed', 'Total_Sky_Cov', 'Opaque_Sky_Cov',
#        'Visibility', 'field_Ceiling_H', 'Whtr_Observ', 'Whtr_Codes',
#        'Pred_Water', 'AeroesOptical_D', 'Snow_Depth', 'Days_Since_Snow',
#        32, 33, 34], dtype=object)

# %%
# create subset dataframe of weather information
NewDf = theDf[['DB_temp',"Dew_Point",
               'RH','P','Normal_Rad', 'Sky_Rad','Wind_Direction', 'Wind_Speed'
              ]]
NewDf.tail()
# Out:
#       DB_temp  Dew_Point  RH  ...  Sky_Rad  Wind_Direction  Wind_Speed
# 8755      5.0       -3.9  51  ...      304             230         8.8
# 8756      4.4       -3.3  55  ...      262             240         7.7
# 8757      4.4       -3.9  53  ...      270             230         7.7
# 8758      5.0       -3.3  53  ...      290             240         7.2
# 8759      5.0       -3.3  53  ...      296             230         7.2
#
# [5 rows x 8 columns]

# %%
# Create index with time series information

# your code here

NewDf.index = myTime
NewDf
# Out:
#                      DB_temp  Dew_Point  ...  Wind_Direction  Wind_Speed
# 2020-01-01 00:00:00      1.7       -3.9  ...             360         6.2
# 2020-01-01 01:00:00      1.7       -3.9  ...             350         5.7
# 2020-01-01 02:00:00      1.1       -3.9  ...             360         6.2
# 2020-01-01 03:00:00      1.1       -3.9  ...              10         5.7
# 2020-01-01 04:00:00      1.1       -4.4  ...              10         5.7
# ...                      ...        ...  ...             ...         ...
# 2020-12-30 19:00:00      5.0       -3.9  ...             230         8.8
# 2020-12-30 20:00:00      4.4       -3.3  ...             240         7.7
# 2020-12-30 21:00:00      4.4       -3.9  ...             230         7.7
# 2020-12-30 22:00:00      5.0       -3.3  ...             240         7.2
# 2020-12-30 23:00:00      5.0       -3.3  ...             230         7.2
#
# [8760 rows x 8 columns]

# %%
NewDf.describe()
# Out:
#            DB_temp    Dew_Point  ...  Wind_Direction   Wind_Speed
# count  8760.000000  8760.000000  ...     8760.000000  8760.000000
# mean     10.599578     3.830559  ...      219.007991     5.484703
# std       9.918710    10.730105  ...       96.724574     2.267986
# min     -20.000000   -32.200000  ...        0.000000     0.000000
# 25%       2.800000    -3.900000  ...      150.000000     4.100000
# 50%      10.600000     4.400000  ...      240.000000     5.200000
# 75%      18.300000    12.800000  ...      300.000000     6.700000
# max      37.200000    23.300000  ...      360.000000    21.600000
#
# [8 rows x 8 columns]

# %%
# Save the dataframe to the file 

# your code here
# Out:
# 'done!!'

# %% [markdown]
# ## Visualization: weather information

# %%
# Import libraries for the visualization
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### Visualize dry bulb temperature with boundary condition

# %%
# your code here


plt.figure(figsize=(15,8))
plt.plot(x,temp)
plt.title('NV potential days')
plt.xlabel('Year')
plt.ylabel('Temperature (F)')
plt.legend(loc='best')

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(15,8))
plt.plot(myTime,temp)
plt.title('NV potential days')
plt.xlabel('Year')
plt.ylabel('Temperature (F)')
plt.legend(loc='best')

# your code here



plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Visualize histogram of relative humidity data

# %%
# your code here


plt.figure(figsize=(15,8))
plt.hist(RH, bins =36, color ="grey", edgecolor='black', alpha = 0.5)
plt.show()

# %% [markdown]
# ## epw file modification

# %%
# Read data
d = getPandasFromFile("",FILEPATH, 8)
d.head(3)
# Out:
#      0   1   2   3   4   ... 30  31     32     33    34
# 0  1976   1   1   1   0  ...  0  88  999.0  999.0  99.0
# 1  1976   1   1   2   0  ...  0  88  999.0  999.0  99.0
# 2  1976   1   1   3   0  ...  0  88  999.0  999.0  99.0
#
# [3 rows x 35 columns]

# %%
# select target values
df_wind = d.iloc[:,21]
print (df_wind)
# Out:
# 0       6.2
# 1       5.7
# 2       6.2
# 3       5.7
# 4       5.7
#        ...
# 8755    8.8
# 8756    7.7
# 8757    7.7
# 8758    7.2
# 8759    7.2
# Name: 21, Length: 8760, dtype: float64

# %%
# Create value list to replace target list
array = []
for i in range (0,len(df_wind)):
    array.append(float(0.1))

d.loc[:,21] = array

# %%
# replace target list to the new list
df_wind = d.iloc[:,21]
print (df_wind)
# Out:
# 0       0.1
# 1       0.1
# 2       0.1
# 3       0.1
# 4       0.1
#        ...
# 8755    0.1
# 8756    0.1
# 8757    0.1
# 8758    0.1
# 8759    0.1
# Name: 21, Length: 8760, dtype: float64

# %%
# Save data frame
d.to_csv("/content/drive/My Drive/Colab Notebooks/J_Term/my2.epw", index=False)
